# %%
# !pip -q install langchain
# !pip install google-cloud-aiplatform
# !pip install gnews
# !pip install unstructured
# Out:
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------- ------------------------------- 1.3/6.2 MB 7.4 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.2 MB 5.4 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.2 MB 5.0 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.2 MB 4.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 4.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------------- ------------------ 0.8/1.4 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    --------- ------------------------------ 1.0/4.3 MB 5.6 MB/s eta 0:00:01
# ...

# %%
from langchain.llms import VertexAI
from langchain.chains.summarize import load_summarize_chain
from langchain.prompts import PromptTemplate
from langchain.document_loaders import UnstructuredURLLoader
# Out:
# c:\Users\tyogo\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (5.2.0)/charset_normalizer (2.0.7) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
from langchain.llms import VertexAI
from langchain.prompts import PromptTemplate
from langchain.chains import load_summarize_chain

# Define the prompt template
prompt_template = """Generate summary for the following text, using the following steps:
                     1. summary consists of a maximum of 100 words
                     2. If the text cannot be found or error, return: "Content empty"
                     3. Use only materials from the text supplied
                     4. Create summary in Bahasa Indonesia

                    "{text}"
                    SUMMARY:"""

prompt = PromptTemplate.from_template(prompt_template)

# Declare the LLM model with proper parameters
llm = VertexAI(
    temperature=0.1,
    model='text-bison@001',
    top_k=40,
    top_p=0.8,
    max_output_token=512,
    _LanguageModel='text-bison@001'
)
VertexAI.model_rebuild()
# # (Optional) Call the model_rebuild method if required by your version of langchain
# llm.model_rebuild()  # Make sure to check if this line is needed based on your setup

# # Load the summarization chain with the LLM and prompt
# summarize_chain = load_summarize_chain(llm, chain_type="map_reduce")

# # Example text for summarization
# text_to_summarize = "Insert the text you want to summarize here."

# # Run the summarization chain
# summary = summarize_chain.run(input_document=text_to_summarize)

# # Print the summary
# print(summary)
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[3], line 18
#      15 prompt = PromptTemplate.from_template(prompt_template)
#      17 # Declare the LLM model with proper parameters
# ---> 18 llm = VertexAI(
#      19     temperature=0.1,
#      20     model='text-bison@001',
#      21     top_k=40,
#      22     top_p=0.8,
#      23     max_output_token=512,
#      24     _LanguageModel='text-bison@001'
#      25 )
#      26 VertexAI.model_rebuild()
#      27 # # (Optional) Call the model_rebuild method if required by your version of langchain
#      28 # llm.model_rebuild()  # Make sure to check if this line is needed based on your setup
#      29
#    (...)
#      39 # # Print the summary
#      40 # print(summary)
#
# ...
